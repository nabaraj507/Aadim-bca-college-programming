# %% [markdown]
# ## python with meachine learning modul 1
#
# ### python
#
# -**Python programming language is a high level,object orinted programming language**
#  In 2026 python is Mostly used programming language
#
# ## why python ?
# - It is simple as simple as english language
# - It has large libary
# - It is object oriented programming language
#
# ## what we are doing?
# - basic of python programming like loops, conditional control variables
# - list types in python list, tuple, dictionary
# - object orinted programming
# - exception handling
# - file handling
# - machine learning
#  - supervised machine learning
#     -regression
#     -classification
# - Web deploy(Django flask)
#
# ## job role in python
# - Web developer (flask, django, fastapi)
# - Security
# - Machine learning
# - Deep learning
# - Web scarping
# - Auto scripting
# - deployment (dovker, kubernetis, krafka,) .yml(python)

# %%
print("hello world!!!!")
# Out:
# hello world

# %%
# int a=10;strongly type programming language(c c++ java c#)
a=10
b=10.20
print(a)
print(type (a))
print(b)
print(type(b))
name= "Nabaraj"
print(name)
print(a,b,name,sep=',')
# Out:
# 10
# <class 'int'>
# 10.2
# <class 'float'>
# Roshan
# 10,10.2,Roshan

# %%
#print hello world

print("hello world")
print("this is new change")
# Out:
# hello world
# this is new change
