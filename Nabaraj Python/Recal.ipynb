# %% [markdown]
# ## python
#
# - high level objective orinted language

# %%
## variable:

name= "python with oop"  ## char name[120]= "python with oop";

a=10.10
b=10

print(name,a,b)

## string interpolation

print(f"the {name} is{name} and is of {type(name)}")
print(f"the value of a is {a} is of {type(a)}")
print(f"the value of b is {b}is of {type(b)}")




## operator 

# arithmatic  (+,-,*,/,%)
# assignment (=,+=,-=,*=,/=,%=)
# relational (<,>,>=,<= ,!=)
# logical ( and,or,not)



## function :
# reusable block of code.


num1 = int(input("inter the number:"))
num2 = float(input("inter the number:"))

def sum( a, b):
 return a+b

print(f" the sum is : {sum(num1,num2)}")

# %% [markdown]
# ## take input from user then calculate sum,div,mul,sub,mod operation using match case.

# %%
# Take input from user
from unittest import case


a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
while True:
    print("Choose operation:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")
    print("6.exit")

    choice = int(input("please select any one: "))

    # Using match-case
    match choice:
        case 1:
            print(" the Sum sum =", a + b)
            
        case 2:
            print(" the Subtraction is =", a - b)
            
        case 3:
            print("Multiplication =", a * b)
        case 4:
            if b != 0:
                print("Division =", a / b)
            else:
                print("Error! Division by zero")
        case 5:
            print("Modulus =", a % b)
        case 6  :
            print("exiting the program...")
            break
# Out:
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6.exit
#  the Sum sum = 10.0
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6.exit
#  the Subtraction is = -2.0
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6.exit
# Multiplication = 24.0
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6.exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 16
#      13 print("5. Modulus")
#      14 print("6.exit")
# ---> 16 choice = int(input("please select any one: "))
#      18 # Using match-case
#      19 match choice:
#
# ValueError: invalid literal for int() with base 10: ''
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# ...
